# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt

# %%
Stats2015 = pd.read_csv('Data/xwOBA2015.csv')
Stats2016 = pd.read_csv('Data/xwOBA2016.csv')
Stats2017 = pd.read_csv('Data/xwOBA2017.csv')

Data = Stats2015.append([Stats2016, Stats2017])

# %%
Data['diff_wOBA'] = Data['xwoba']-Data['woba']

# %%
Data.sort_values('diff_wOBA', ascending=True)
# Out:
#      pitches  player_id           player_name  year  total_pitches  \
# 198     2248     543829            Dee Gordon  2015           2248
# 206     1947     542993           Billy Burns  2015           1947
# 204     1721     456488         Eduardo Nunez  2017           1721
# 127     2114     503556       Marwin Gonzalez  2017           2114
# 92      2125     446359           Zack Cozart  2017           2125
# 199     1692     592696         Eddie Rosario  2015           1692
# 213     2397     543829            Dee Gordon  2017           2397
# 200     1692     578428         Jose Iglesias  2015           1692
# 5       2683     547180          Bryce Harper  2015           2683
# 211     1814     592261      Delino DeShields  2017           1814
# 127     1744     649557          Aledmys Diaz  2016           1744
# 144     2227     514888           Jose Altuve  2015           2227
# 195     1666     595281       Kevin Kiermaier  2017           1666
# ...

# %%
Data.corr(method='pearson')
# Out:
#                           pitches  player_id      year  total_pitches  \
# pitches                  1.000000  -0.045205  0.037737       1.000000
# player_id               -0.045205   1.000000  0.197772      -0.045205
# year                     0.037737   0.197772  1.000000       0.037737
# total_pitches            1.000000  -0.045205  0.037737       1.000000
# pitch_percent                 NaN        NaN       NaN            NaN
# ba                       0.227684   0.056569  0.003552       0.227684
# iso                      0.326062   0.016980  0.225999       0.326062
# babip                    0.097630   0.206460  0.006586       0.097630
# slg                      0.384415   0.038648  0.199020       0.384415
# woba                     0.449896   0.009484  0.136454       0.449896
# xwoba                    0.437140  -0.142106  0.168484       0.437140
# xba                      0.282718  -0.160330  0.002722       0.282718
# ...

# %%
Stats2018 = pd.read_csv('Data/xwOBA2018.csv')

# %%
Stats2018['diff_wOBA'] = Stats2018['xwoba']-Stats2018['woba']

# %%
Stats2018.sort_values('diff_wOBA', ascending=True)
# Out:
#      pitches  player_id           player_name  total_pitches  pitch_percent  \
# 240     1037     546991     Albert Almora Jr.           1037          100.0
# 245      843     664056        Harrison Bader            843          100.0
# 231     1105     605480          Mallex Smith           1105          100.0
# 232     1030     608597         Ronald Guzman           1030          100.0
# 145     1486     592696         Eddie Rosario           1486          100.0
# 208     1539     546318        Odubel Herrera           1539          100.0
# 175     1381     575929     Willson Contreras           1381          100.0
# 39      1612     571448         Nolan Arenado           1612          100.0
# 191     1038     471865       Carlos Gonzalez           1038          100.0
# 247      995     608671      Travis Jankowski            995          100.0
# 201     1118     493329          Yuli Gurriel           1118          100.0
# ...
